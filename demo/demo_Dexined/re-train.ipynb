# %% [markdown]
# # Load packages

# %%
from pathlib import Path
project_root = Path("/home/yangk/intership_2025_COSYS")

# %%
import torch
import torch.nn as nn
from torch.utils.data.dataloader import DataLoader
import json
import numpy as np

# %%
import sys

sys.path.append(str(project_root / "resource/DexiNed"))
sys.path.append(str(project_root / "src"))

from model import DexiNed
from dataset import BIPEDv2, transforms

# %% [markdown]
# # Prepare

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
epoch = 50
batch_size = 8
learning_rate = 1e-4
biped_dataset = BIPEDv2(
    project_root / "data/BIPEDv2/BIPED/edges/imgs/train/rgbr/real/",
    project_root / "data/BIPEDv2/BIPED/edges/edge_maps/train/rgbr/real/"
)
# test set
test_dataset = BIPEDv2(
    project_root / "data/BIPEDv2/BIPED/edges/imgs/test/rgbr/",
    project_root / "data/BIPEDv2/BIPED/edges/edge_maps/test/rgbr/"
)

model = DexiNed()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
loader = DataLoader(biped_dataset, batch_size=8)
val_loader = DataLoader(test_dataset, batch_size=8)
logging = {
    'metadata': {},
    'train_loss': [],
    'val_loss': []
}


print(device)
# Out:
# cuda

# %% [markdown]
# # Train

# %%
import os
# set checkpoint file name
# file_stem = "cpt_visibility_06"
logging['metadata'] = {
    "description": "re-train", 
    "num_epoch":epoch, 
    "batch_size":batch_size, 
    "criterion": criterion.__class__.__name__, 
    "learning_rate": learning_rate
}

prefix = project_root / "data/checkpoints/torch_point08"
model_path = prefix / "model.pth"
log_path = prefix / "log.json"

# if not os.path.isfile(str(prefix / f"{file_stem}.json")): # First train
if not prefix.is_dir(): # First train
    prefix.mkdir()
    model = model.to(device)
    for e in range(epoch):
        # train step
        model.train()
        epoche_loss = []
        for batch in loader:
            x, y = batch['image_tensor'], batch['visibility_map']
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            outputs = model(x)
            loss = sum([criterion(output.squeeze(), y) for output in outputs]) / len(outputs)
            loss.backward()
            optimizer.step()
            print("*", end="", flush=True)
            epoche_loss.append(loss.detach().item())
        logging['train_loss'].append(np.mean(epoche_loss))
        print(f"\nIn epoch {e}, the average  training  loss is {logging['train_loss'][-1]}")
        # validation step
        model.eval()
        val_epoch_loss = []
        with torch.no_grad():
            for batch in val_loader:
                x, y = batch['image_tensor'], batch['visibility_map']
                x, y = x.to(device), y.to(device)
                outputs = model(x)
                loss = sum([criterion(output.squeeze(), y) for output in outputs]) / len(outputs)
                val_epoch_loss.append(loss.detach().item())
        logging['val_loss'].append(np.mean(val_epoch_loss))
        print(f"In epoch {e}, the average validation loss is {logging['val_loss'][-1]}")
    model = model.to('cpu')
    # save files
    # file_stem = "cpt_visibility_01"
    torch.save(model.state_dict(), str(model_path))
    print(f"Succeed saving mdoel parameters in {model_path}.")
    with open(str(log_path), "w") as f:
        json.dump(logging, f)
    print(f"Succeed saving log in {log_path}.")
else: # already trained
    # load model
    model.load_state_dict(torch.load(str(model_path), weights_only=True))
    # # load log
    with open(str(log_path), 'r') as f:
        logging = json.load(f)
    # # print the loss
    for e, (train_loss, val_loss) in enumerate(zip(logging['train_loss'], logging['val_loss'])):
        print("-".join(["-"]*30))
        print(f"In epoch {e}, the average  training  loss is {train_loss}")
        print(f"In epoch {e}, the average validation loss is {val_loss}")
# Out:
# -----------------------------------------------------------
# In epoch 0, the average  training  loss is 647.7779647827149
# In epoch 0, the average validation loss is 695.3906531700721
# -----------------------------------------------------------
# In epoch 1, the average  training  loss is 636.5498034667969
# In epoch 1, the average validation loss is 682.571767953726
# -----------------------------------------------------------
# In epoch 2, the average  training  loss is 629.8177453613281
# In epoch 2, the average validation loss is 677.2847876915565
# -----------------------------------------------------------
# In epoch 3, the average  training  loss is 626.3993243408203
# In epoch 3, the average validation loss is 675.0049532376803
# -----------------------------------------------------------
# In epoch 4, the average  training  loss is 624.0332815551758
# In epoch 4, the average validation loss is 672.7822429950421
# -----------------------------------------------------------
# In epoch 5, the average  training  loss is 622.1370806884765
# In epoch 5, the average validation loss is 671.2144329364484
# -----------------------------------------------------------
# In epoch 6, the average  training  loss is 620.4795321655273
# In epoch 6, the average validation loss is 670.2857853816106
# -----------------------------------------------------------
# In epoch 7, the average  training  loss is 618.9049749755859
# In epoch 7, the average validation loss is 669.1152038574219
# -----------------------------------------------------------
# In epoch 8, the average  training  loss is 617.4305084228515
# In epoch 8, the average validation loss is 668.1472003643329
# -----------------------------------------------------------
# In epoch 9, the average  training  loss is 616.0420385742187
# In epoch 9, the average validation loss is 666.6029428335337
# -----------------------------------------------------------
# In epoch 10, the average  training  loss is 614.6438931274414
# In epoch 10, the average validation loss is 665.1234529935397
# -----------------------------------------------------------
# In epoch 11, the average  training  loss is 613.2150180053711
# In epoch 11, the average validation loss is 664.8737722543569
# -----------------------------------------------------------
# In epoch 12, the average  training  loss is 612.2203939819336
# In epoch 12, the average validation loss is 664.5278484637921
# -----------------------------------------------------------
# In epoch 13, the average  training  loss is 610.7828463745117
# In epoch 13, the average validation loss is 662.9058532714844
# -----------------------------------------------------------
# In epoch 14, the average  training  loss is 607.6328326416016
# In epoch 14, the average validation loss is 657.1216641939603
# -----------------------------------------------------------
# In epoch 15, the average  training  loss is 603.2250598144532
# In epoch 15, the average validation loss is 653.5791320800781
# -----------------------------------------------------------
# In epoch 16, the average  training  loss is 599.3665185546874
# In epoch 16, the average validation loss is 649.2297715407151
# -----------------------------------------------------------
# In epoch 17, the average  training  loss is 596.8831521606445
# In epoch 17, the average validation loss is 648.9520639272837
# -----------------------------------------------------------
# In epoch 18, the average  training  loss is 595.0859368896485
# In epoch 18, the average validation loss is 648.4775015024038
# -----------------------------------------------------------
# In epoch 19, the average  training  loss is 593.7497540283204
# In epoch 19, the average validation loss is 646.7660498985878
# -----------------------------------------------------------
# In epoch 20, the average  training  loss is 592.7956280517578
# In epoch 20, the average validation loss is 646.9779545710637
# -----------------------------------------------------------
# In epoch 21, the average  training  loss is 592.1094769287109
# In epoch 21, the average validation loss is 648.7885812612681
# -----------------------------------------------------------
# In epoch 22, the average  training  loss is 591.0072296142578
# In epoch 22, the average validation loss is 645.482435960036
# -----------------------------------------------------------
# In epoch 23, the average  training  loss is 589.617706604004
# In epoch 23, the average validation loss is 644.0242262620193
# -----------------------------------------------------------
# In epoch 24, the average  training  loss is 588.7493603515625
# In epoch 24, the average validation loss is 643.7418987567609
# -----------------------------------------------------------
# In epoch 25, the average  training  loss is 588.0136853027344
# In epoch 25, the average validation loss is 643.6711848332332
# -----------------------------------------------------------
# In epoch 26, the average  training  loss is 586.4541857910157
# In epoch 26, the average validation loss is 641.2714515099159
# -----------------------------------------------------------
# In epoch 27, the average  training  loss is 584.9944033813476
# In epoch 27, the average validation loss is 641.5855712890625
# -----------------------------------------------------------
# In epoch 28, the average  training  loss is 583.9281253051757
# In epoch 28, the average validation loss is 642.0693758451022
# -----------------------------------------------------------
# In epoch 29, the average  training  loss is 582.837158203125
# In epoch 29, the average validation loss is 641.0878835824819
# -----------------------------------------------------------
# In epoch 30, the average  training  loss is 581.4030114746093
# In epoch 30, the average validation loss is 641.7986403245193
# -----------------------------------------------------------
# In epoch 31, the average  training  loss is 579.7207052612305
# In epoch 31, the average validation loss is 638.9116774338943
# -----------------------------------------------------------
# In epoch 32, the average  training  loss is 578.5853762817383
# In epoch 32, the average validation loss is 638.5653897798978
# -----------------------------------------------------------
# In epoch 33, the average  training  loss is 577.1031759643555
# In epoch 33, the average validation loss is 636.7191443810096
# -----------------------------------------------------------
# In epoch 34, the average  training  loss is 575.3095098876953
# In epoch 34, the average validation loss is 636.8821505033053
# -----------------------------------------------------------
# In epoch 35, the average  training  loss is 573.9931558227539
# In epoch 35, the average validation loss is 637.6880375788762
# -----------------------------------------------------------
# In epoch 36, the average  training  loss is 573.2141607666016
# In epoch 36, the average validation loss is 636.118657038762
# -----------------------------------------------------------
# In epoch 37, the average  training  loss is 572.434613647461
# In epoch 37, the average validation loss is 634.1956176757812
# -----------------------------------------------------------
# In epoch 38, the average  training  loss is 570.488568725586
# In epoch 38, the average validation loss is 634.210453913762
# -----------------------------------------------------------
# In epoch 39, the average  training  loss is 569.4668682861328
# In epoch 39, the average validation loss is 634.2929382324219
# -----------------------------------------------------------
# In epoch 40, the average  training  loss is 568.3623297119141
# In epoch 40, the average validation loss is 634.7051555926984
# -----------------------------------------------------------
# In epoch 41, the average  training  loss is 566.1526168823242
# In epoch 41, the average validation loss is 634.821547288161
# -----------------------------------------------------------
# In epoch 42, the average  training  loss is 564.8462109375
# In epoch 42, the average validation loss is 634.9825110802284
# -----------------------------------------------------------
# In epoch 43, the average  training  loss is 563.923860168457
# In epoch 43, the average validation loss is 632.2570988581731
# -----------------------------------------------------------
# In epoch 44, the average  training  loss is 563.4546203613281
# In epoch 44, the average validation loss is 631.756587101863
# -----------------------------------------------------------
# In epoch 45, the average  training  loss is 562.0340270996094
# In epoch 45, the average validation loss is 633.1301339956431
# -----------------------------------------------------------
# In epoch 46, the average  training  loss is 560.9898645019531
# In epoch 46, the average validation loss is 630.122807429387
# -----------------------------------------------------------
# In epoch 47, the average  training  loss is 559.2688519287109
# In epoch 47, the average validation loss is 629.4821542593149
# -----------------------------------------------------------
# In epoch 48, the average  training  loss is 557.3641662597656
# In epoch 48, the average validation loss is 630.0742469200721
# -----------------------------------------------------------
# In epoch 49, the average  training  loss is 556.2034619140625
# In epoch 49, the average validation loss is 631.9027921236478
# -----------------------------------------------------------
# In epoch 50, the average  training  loss is 555.3159426879882
# In epoch 50, the average validation loss is 630.7860576923077
# -----------------------------------------------------------
# In epoch 51, the average  training  loss is 554.5355139160156
# In epoch 51, the average validation loss is 631.5981234036959
# -----------------------------------------------------------
# In epoch 52, the average  training  loss is 553.638635559082
# In epoch 52, the average validation loss is 633.2999807504507
# -----------------------------------------------------------
# In epoch 53, the average  training  loss is 552.4058087158203
# In epoch 53, the average validation loss is 634.6503155048077
# -----------------------------------------------------------
# In epoch 54, the average  training  loss is 550.8376522827149
# In epoch 54, the average validation loss is 630.4407559908353
# -----------------------------------------------------------
# In epoch 55, the average  training  loss is 548.9988488769532
# In epoch 55, the average validation loss is 629.7436992938702
# -----------------------------------------------------------
# In epoch 56, the average  training  loss is 547.1576455688477
# In epoch 56, the average validation loss is 634.5558236929087
# -----------------------------------------------------------
# In epoch 57, the average  training  loss is 546.325805053711
# In epoch 57, the average validation loss is 632.6965566781851
# -----------------------------------------------------------
# In epoch 58, the average  training  loss is 545.1852416992188
# In epoch 58, the average validation loss is 630.8512690617488
# -----------------------------------------------------------
# In epoch 59, the average  training  loss is 543.9055590820312
# In epoch 59, the average validation loss is 629.3411348783053
# -----------------------------------------------------------
# In epoch 60, the average  training  loss is 542.8721453857422
# In epoch 60, the average validation loss is 629.3201270470253
# -----------------------------------------------------------
# In epoch 61, the average  training  loss is 541.4264260864257
# In epoch 61, the average validation loss is 630.2368962214543
# -----------------------------------------------------------
# In epoch 62, the average  training  loss is 539.7641906738281
# In epoch 62, the average validation loss is 629.4321101262019
# -----------------------------------------------------------
# In epoch 63, the average  training  loss is 537.6708917236328
# In epoch 63, the average validation loss is 630.4160977877103
# -----------------------------------------------------------
# In epoch 64, the average  training  loss is 535.9331039428711
# In epoch 64, the average validation loss is 638.3592693622296
# -----------------------------------------------------------
# In epoch 65, the average  training  loss is 535.7820266723633
# In epoch 65, the average validation loss is 630.1182227501503
# -----------------------------------------------------------
# In epoch 66, the average  training  loss is 535.0823760986328
# In epoch 66, the average validation loss is 626.9443641075721
# -----------------------------------------------------------
# In epoch 67, the average  training  loss is 532.8791165161133
# In epoch 67, the average validation loss is 624.5164489746094
# -----------------------------------------------------------
# In epoch 68, the average  training  loss is 530.3364916992188
# In epoch 68, the average validation loss is 625.0155005821815
# -----------------------------------------------------------
# In epoch 69, the average  training  loss is 528.5548315429687
# In epoch 69, the average validation loss is 630.0962242713341
# -----------------------------------------------------------
# In epoch 70, the average  training  loss is 526.8993716430664
# In epoch 70, the average validation loss is 632.5753666804387
# -----------------------------------------------------------
# In epoch 71, the average  training  loss is 523.7337826538086
# In epoch 71, the average validation loss is 630.9952275202825
# -----------------------------------------------------------
# In epoch 72, the average  training  loss is 525.2137408447265
# In epoch 72, the average validation loss is 627.829603928786
# -----------------------------------------------------------
# In epoch 73, the average  training  loss is 524.5484744262695
# In epoch 73, the average validation loss is 627.645033616286
# -----------------------------------------------------------
# In epoch 74, the average  training  loss is 522.7287683105469
# In epoch 74, the average validation loss is 637.5262920673077
# -----------------------------------------------------------
# In epoch 75, the average  training  loss is 520.1993103027344
# In epoch 75, the average validation loss is 635.9063791128306
# -----------------------------------------------------------
# In epoch 76, the average  training  loss is 517.3059631347656
# In epoch 76, the average validation loss is 630.4104637732872
# -----------------------------------------------------------
# In epoch 77, the average  training  loss is 517.0000604248047
# In epoch 77, the average validation loss is 624.4655550443209
# -----------------------------------------------------------
# In epoch 78, the average  training  loss is 513.7112115478516
# In epoch 78, the average validation loss is 621.7606811523438
# -----------------------------------------------------------
# In epoch 79, the average  training  loss is 513.4515036010743
# In epoch 79, the average validation loss is 620.506361741286
# -----------------------------------------------------------
# In epoch 80, the average  training  loss is 512.4037994384765
# In epoch 80, the average validation loss is 621.8532174917368
# -----------------------------------------------------------
# In epoch 81, the average  training  loss is 510.30333038330076
# In epoch 81, the average validation loss is 620.7990276630109
# -----------------------------------------------------------
# In epoch 82, the average  training  loss is 507.27009368896483
# In epoch 82, the average validation loss is 622.8338270920974
# -----------------------------------------------------------
# In epoch 83, the average  training  loss is 505.22205963134763
# In epoch 83, the average validation loss is 621.0943908691406
# -----------------------------------------------------------
# In epoch 84, the average  training  loss is 504.4459097290039
# In epoch 84, the average validation loss is 621.3557410606971
# -----------------------------------------------------------
# In epoch 85, the average  training  loss is 504.7897076416016
# In epoch 85, the average validation loss is 625.2802922175481
# -----------------------------------------------------------
# In epoch 86, the average  training  loss is 504.45685607910156
# In epoch 86, the average validation loss is 630.8526235727163
# -----------------------------------------------------------
# In epoch 87, the average  training  loss is 501.87500640869143
# In epoch 87, the average validation loss is 630.8226858285757
# -----------------------------------------------------------
# In epoch 88, the average  training  loss is 498.76315338134765
# In epoch 88, the average validation loss is 625.3899137056791
# -----------------------------------------------------------
# In epoch 89, the average  training  loss is 496.0059231567383
# In epoch 89, the average validation loss is 622.017573429988
# -----------------------------------------------------------
# In epoch 90, the average  training  loss is 495.2880453491211
# In epoch 90, the average validation loss is 619.9059307391827
# -----------------------------------------------------------
# In epoch 91, the average  training  loss is 494.7438461303711
# In epoch 91, the average validation loss is 615.7066157414363
# -----------------------------------------------------------
# In epoch 92, the average  training  loss is 493.0033645629883
# In epoch 92, the average validation loss is 618.449451153095
# -----------------------------------------------------------
# In epoch 93, the average  training  loss is 490.7407080078125
# In epoch 93, the average validation loss is 616.43311720628
# -----------------------------------------------------------
# In epoch 94, the average  training  loss is 489.6542004394531
# In epoch 94, the average validation loss is 616.997563288762
# -----------------------------------------------------------
# In epoch 95, the average  training  loss is 489.7702932739258
# In epoch 95, the average validation loss is 621.4983684833234
# -----------------------------------------------------------
# In epoch 96, the average  training  loss is 487.8139437866211
# In epoch 96, the average validation loss is 619.4893869253306
# -----------------------------------------------------------
# In epoch 97, the average  training  loss is 484.95280670166017
# In epoch 97, the average validation loss is 619.9983520507812
# -----------------------------------------------------------
# In epoch 98, the average  training  loss is 484.3462799072266
# In epoch 98, the average validation loss is 617.5266394981971
# -----------------------------------------------------------
# In epoch 99, the average  training  loss is 482.663137512207
# In epoch 99, the average validation loss is 615.2142028808594

# %% [markdown]
# # Result

# %%
from PIL import Image
# take one example
item= biped_dataset.__getitem__(6)
img, x, y = Image.open(item['image_path']).convert('RGB'), item['image_tensor'], item['visibility_map']
# x = biped_dataset.transform(img)
# inference
model.eval()
with torch.no_grad():
    model.to(device)
    yhat = model(x.unsqueeze(0).to(device))[-1].squeeze()
    yhat = yhat.to('cpu')
    model.to('cpu')

# %%
# NMS
from nms import get_gradient_canny, nms_fully_vectorized

gx, gy = get_gradient_canny(x.mean(dim=0))
yhat = nms_fully_vectorized(yhat, gx, gy)

# %%
import matplotlib.pyplot as plt
import numpy as np

# display
fig, axes = plt.subplots(2, 2, figsize=(16, 9))

# Loss
axes[0,0].plot(logging['train_loss'])
axes[0,0].plot(logging['val_loss'])
axes[0,0].set_xlabel("epoch")
axes[0,0].set_title("Epoch Loss")

# original image
axes[0,1].imshow(img)
axes[0,1].set_title("Original image")
# axes[0,1].axis('off')  # 不显示坐标轴

# edge
def normalisation(img, denom=80):
    res = img / denom
    res = np.where(res<0, 0, res)
    res = np.where(res>1, 1, res) 
    return res
axes[1,0].imshow(normalisation(yhat, 80), cmap="gray")
axes[1,0].set_title("Prediction")
# axes[1,0].axis('off')  # 不显示坐标轴
axes[1,1].imshow(normalisation(y, 80), cmap="gray")
axes[1,1].set_title("GT")
# axes[1,1].axis('off')  # 不显示坐标轴

plt.tight_layout()  # 自动调整子图间距
plt.show()

# %%
yhat.shape
# Out:
# torch.Size([720, 1280])

# %%
import matplotlib.pyplot as plt
import numpy as np

# display
fig, axes = plt.subplots(2, 2, figsize=(16, 9))

# Loss
axes[0,0].imshow(normalisation(yhat, 80), cmap="gray")
axes[0,0].set_title("yhat")

gx, gy = get_gradient_canny(yhat)
nms_edge = nms_fully_vectorized(yhat, gx, gy)
axes[0,1].imshow(normalisation(nms_edge, 80), cmap="gray")
axes[0,1].set_title("G with yhat")

gx, gy = get_gradient_canny(transforms.ToTensor()(img.convert("L")).squeeze())
nms_edge = nms_fully_vectorized(yhat, gx, gy)
axes[1,0].imshow(normalisation(nms_edge, 80), cmap="gray")
axes[1,0].set_title("G with image")

gx, gy = get_gradient_canny(x.mean(dim=0))
nms_edge = nms_fully_vectorized(yhat, gx, gy)
axes[1,1].imshow(normalisation(nms_edge, 80), cmap="gray")
axes[1,1].set_title("G with x")

plt.tight_layout()  # 自动调整子图间距
plt.show()

# %%
# 测试NMS加入model
from nms import get_gradient_canny, nms_fully_vectorized

model.to(device)
batch = next(iter(loader))
x, y = batch['image_tensor'].to(device), batch['visibility_map'].to(device)
outputs = model(x)

# NMS
gx, gy = get_gradient_canny(x.mean(dim=1))
outputs[-1] = nms_fully_vectorized(outputs[-1].squeeze(), gx, gy).unsqueeze(1)
# loss = loss_func(outputs, y, criterion) # sum([criterion(output, y) for output in outputs]) / len(outputs)

# %%
outputs[-1].shape
# Out:
# torch.Size([8, 1, 720, 1280])

# %%
sum([1,2,3,4,5])
# Out:
# 15

# %%
# from nms import apply_gaussian_blur

# [[1,1,1],
#  [1,1/8, 1],
#  [1,1,1]
# ]
# filtre max sur une fenetre 3x3 (dilatation)

import torch
import torch.nn.functional as F

y_dilatation = F.max_pool2d(y.unsqueeze(1), 3, stride=1, padding=1).squeeze(1).to('cpu')

# %%
y_dilatation.shape
# Out:
# torch.Size([8, 720, 1280])

# %%
plt.imshow(y_dilatation[0], cmap="gray")
plt.show()

# %%
plt.figure(figsize=(4, 2))
plt.text(0.5, 0.5, r"$\frac{1}{3}$", fontsize=20, ha='center', va='center')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure(figsize=(4, 2))
#       2 plt.text(0.5, 0.5, r"$\frac{1}{3}$", fontsize=20, ha='center', va='center')
#       3 plt.axis('off')
#
# NameError: name 'plt' is not defined
